# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
list1=np.random.rand(100)
list2=np.random.rand(100)
pan=pd.Series(list1,index=list2)
plt.plot(list1,list2,'.')
my_cir=plt.Circle((0.5,0.5),0.5,color='r',alpha=0.85)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-09d680969dfe> in <module>
#       4 plt.plot(list1,list2,'.')
#       5 my_cir=plt.Circle((0.5,0.5),0.5,color='r',alpha=0.85)
# ----> 6 plt.plot(my_cir,'.')
#       7 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
cir=np.sqrt(list1**2+list2**2)
plt.plot(cir)
plt.show()
